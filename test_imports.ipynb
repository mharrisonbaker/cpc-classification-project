# %%
# In Python interactive shell or script:
from src.pipeline.batch_processor import definition_expander
print(dir(definition_expander))
# Out:
# 🟢 Available VRAM: 14914MB
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 # In Python interactive shell or script:
# ----> 2 from src.pipeline.batch_processor import definition_expander
#       3 print(dir(definition_expander))
#
# File c:\Development\cpc-classification-project\src\pipeline\__init__.py:3
#       1 from .xml_processor.extractor import extract_cpc_zip, get_latest_cpc_version, download_cpc_zip, ensure_directory_exists
#       2 from .json_processor.converter import convert_xml_to_json, parse_cpc_scheme
# ----> 3 from .batch_processor.definition_expander import CPCDefinitionExpander
#       5 __all__ = [
#       6     'extract_cpc_zip',
#       7     'get_latest_cpc_version',
#    (...)
#      12     'CPCDefinitionExpander'
#      13 ]
#
# File c:\Development\cpc-classification-project\src\pipeline\batch_processor\__init__.py:2
# ...
